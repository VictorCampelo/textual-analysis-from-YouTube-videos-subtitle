# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorCampelo/textual-analysis-from-YouTube-videos-subtitle/blob/master/yt_transcript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
transcript_list = YouTubeTranscriptApi.list_transcripts('Fbu7z5dXcRs&t=1848s')

# %%
transcript = transcript_list.find_transcript(['pt'])

# %%
print(
    transcript.video_id,
    transcript.language,
    transcript.language_code,
    # whether it has been manually created or generated by YouTube
    transcript.is_generated,
    # whether this transcript can be translated or not
    transcript.is_translatable
)
# Out:
# Fbu7z5dXcRs&t=1848s Portuguese (auto-generated) pt True True

# %%
transcript.fetch()[1]['text']
# Out:
# 'muito massa pra gente falar um pouquinho'

# %%
text = ' '.join([obj['text'] for obj in transcript.fetch()])

# %%
pip install nltk

# %%
import nltk
from nltk.text import Text
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import gutenberg

# %%
tokens = nltk.word_tokenize(texto)
text = nltk.Text(tokens)

# %%
text.concordance('beleza')
# Out:
# Displaying 25 of 96 matches:
# a que a gente chama de esquema free beleza basicamente esquema free quer dizer
# mos fazer um pouco mais de trabalho beleza então beleza demais atuam explicou
# pouco mais de trabalho beleza então beleza demais atuam explicou um pouquinho
# e aplicação utilizando um banco sql beleza e aí depois você pode separar parte
#  bebê para coisas muito específicas beleza então vamos lá chega de falatório e
# d s mexe ele retorna em hello world beleza aqui não estou utilizando um banco
# o aí a gente tem aí o kerry builder beleza que hoje no node o mais famoso é o
# nc e depois é brian cinep em carson beleza então basicamente isso aqui é o nív
# dbs light oracle ou amazon redshift beleza e ele vai funcionar mais em outros
# um momento vai funcionar tudo igual beleza e o next ele já tem suporte aquilo
# cionar relacionamentos e por aí vai beleza então a gente vai ver como isso fic
# eu vou mostrar isso aqui na prática beleza então a gente vai já conhecer o que
# ...

# %%
text.dispersion_plot(['beleza', 'eu', 'você', 'agora'])

# %%
len(set(text))
# Out:
# 2239

# %%
len(text)
# Out:
# 19675

# %%
len(set(text))/len(text)
# Out:
# 0.1137992376111817
